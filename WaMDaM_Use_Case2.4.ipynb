# %% [markdown]
# ### Use Case 2.4: What differences are there across datasets in dam heights, installed hydropower capacity, and number of generators for two reservoirs?
#
# This notebook demonstrates basic WaMDaM use cases analysis using scientific Python libraries such as [pandas](https://pandas.pydata.org/) and [plotly](https://plot.ly/).  It reads WaMDaM SQLite data from a published HydroShare Generic Resource, runs SQL script, and them uses Python plotly to visualize the results
#
# This use case identifies five volume-elevation curves for Hyrum Reservoir, Utah from three datasets: USBOR, Utah Dams, and WEAP model datasets
#
# For more info: http://docs.wamdam.org/UseCases/use_case_2/#use-case-2.4

# %%
import os
from utilities import hydroshare
#from hs_restclient import HydroShare

import sqlite3
import numpy as np
import pandas as pd

# %%
# !pip install plotly  # python 2.7
# !pip3 install plotly # python3
# !conda install -c plotly plotly -y

# %% [markdown]
# WaMDaM database test file (SQLite) on HydroShare
# https://www.hydroshare.org/resource/1601e9f029984a87affcd94af6b4bad0/

# %% [markdown]
# import os
# from utilities import hydroshare
# #from hs_restclient import HydroShare
#
# import sqlite3
# import numpy as np
# import pandas as pd

# %% [markdown]
# Next we need to establish a secure connection with HydroShare. This is done by simply instantiating the hydroshare class that is defined within hs_utils. In addition to connecting with HydroShare, this command also sets environment variables for several parameters that may useful to you:
#
# Your username
# The ID of the resource which launched the notebook
# The type of resource that launched this notebook
# The url for the notebook server.

# %%
# establish a secure connection to HydroShare
hs = hydroshare.hydroshare()
# Out:
# Adding the following system variables:
#    HS_USR_NAME = amabdallah
#    HS_RES_ID = 0213b70855fd4a59b73a18fd0a69985a
#    HS_RES_TYPE = genericresource
#    JUPYTER_HUB_IP = jupyter.cuahsi.org
#
# These can be accessed using the following command:
#    os.environ[key]
#
#    (e.g.)
#    os.environ["HS_USR_NAME"]  => amabdallah
# Successfully established a connection with HydroShare

# %%
### Retrieve a resource using its ID

# The data for our processing routines can be retrieved using the `getResourceFromHydroShare` function by passing it the global identifier from the url above
# get some resource content. The resource content is returned as a dictionary
# Abdallah, A. (2018). Bear River Datasets, HydroShare, http://www.hydroshare.org/resource/bec9b20118804d119c4bfc232caea559
content = hs.getResourceFromHydroShare('bec9b20118804d119c4bfc232caea559')
# Out:
# This resource already exists in your userspace.
# Would you like to overwrite this data [Y/n]? Y
# Download Finished
# Successfully downloaded resource bec9b20118804d119c4bfc232caea559
# <b>Found the following file(s) associated with this HydroShare resource.</b>
# BearRiverDatasets_Jan2018.sqlite
# These files are stored in a dictionary called <b>hs.content</b> for your convenience.  To access a file, simply issue the following command where MY_FILE is one of the files listed above: <pre>hs.content["MY_FILE"] </pre>

# %%
# Use SQLite engine to connect to the SQLite file. 
# Then we can run queries against it within this notebook :)  
conn = sqlite3.connect(hs.content["BearRiverDatasets_Jan2018.sqlite"])

# %% [markdown]
# # Compare Shasta and Flaming Gorge Reservoirs

# %%
# Query multiple MultipleDescriptorValues_HydroPower
# This query shows the list of Reservoirs in Utah that have HydroPower purpose in the US Major Dams dataset


# 4.2MultiAttributeValues.csv
import urllib

# for simplicity, we call the query directly from GitHub as a text. You may use the query here but it will be too long to show in a cell 
# https://github.com/WamdamProject/WaMDaM_UseCases/blob/master/UseCases_files/4Queries_SQL/UseCase2/UseCase2.4/1_MultipleDescriptorValues_HydroPower.sql

txt1 = urllib.urlopen("https://raw.githubusercontent.com/WamdamProject/WaMDaM_UseCases/master/UseCases_files/4Queries_SQL/UseCase2/UseCase2.4/2_CompareShastaFlamingGorge.sql").read()

# pass the query to the SQLite connection
df = pd.read_sql_query(txt1, conn)

# Save the query result into a CSV file
df.to_csv('query_resut.csv')

# to print the table result here within the notebook, just uncomment the df line below
df
# Out:
#   DatasetAcronymDamHEIGHT  InstanceNameCVDamHEIGHT  DamHEIGHT UnitNameHeight  \
# 0           US Major Dams         Shasta Reservoir      602.0           foot
# 1           US Major Dams  Flaming Gorge Reservoir      502.0           foot
# 2           US Major Dams          Hyrum Reservoir      116.0           foot
# 3           US Major Dams         Cutler Reservoir      114.0           foot
#
#    InstalledCapacity UnitNameCap  N_Gen
# 0              714.0    Megawatt    7.0
# 1              151.8    Megawatt    3.0
# 2                0.5    Megawatt    1.0
# 3               30.0    Megawatt    2.0

# %% [markdown]
# # Hydropower in Utah

# %% [markdown]
# ## HydroPower purpose in the US Major Dams dataset

# %%
# Query multiple MultipleDescriptorValues_HydroPower
# This query shows the list of Reservoirs in Utah that have HydroPower purpose in the US Major Dams dataset


# 4.2MultiAttributeValues.csv
import urllib

# for simplicity, we call the query directly from GitHub as a text. You may use the query here but it will be too long to show in a cell 
# https://github.com/WamdamProject/WaMDaM_UseCases/blob/master/UseCases_files/4Queries_SQL/UseCase2/UseCase2.4/1_MultipleDescriptorValues_HydroPower.sql

txt1 = urllib.urlopen("https://raw.githubusercontent.com/WamdamProject/WaMDaM_UseCases/master/UseCases_files/4Queries_SQL/UseCase2/UseCase2.4/1_HydroPower_UT_USDams.sql").read()

# pass the query to the SQLite connection
df = pd.read_sql_query(txt1, conn)

# Save the query result into a CSV file
df.to_csv('query_resut.csv')

# to print the table result here within the notebook, just uncomment the df line below
df
# Out:
#   DatasetAcronymPurpose          InstanceNamePurpose DescriptorValuePurpose  \
# 0         US Major Dams                      GUNLOCK                      H
# 1         US Major Dams                       VERNON                      H
# 2         US Major Dams                SOLDIER CREEK                      H
# 3         US Major Dams                   DEER CREEK                      H
# 4         US Major Dams                      WANSHIP                      H
# 5         US Major Dams                FLAMING GORGE                      H
# 6         US Major Dams                         ECHO                      H
# 7         US Major Dams                     PINEVIEW                      H
# 8         US Major Dams  UTAH POWER & LIGHT - CUTLER                      H
#
#   DatasetAcronymState            InstanceNameState DescriptorValueState
# 0       US Major Dams                      GUNLOCK                   UT
# 1       US Major Dams                       VERNON                   UT
# 2       US Major Dams                SOLDIER CREEK                   UT
# 3       US Major Dams                   DEER CREEK                   UT
# 4       US Major Dams                      WANSHIP                   UT
# 5       US Major Dams                FLAMING GORGE                   UT
# 6       US Major Dams                         ECHO                   UT
# 7       US Major Dams                     PINEVIEW                   UT
# 8       US Major Dams  UTAH POWER & LIGHT - CUTLER                   UT

# %% [markdown]
# ## Utah Hydropower Plants

# %%
# Query multiple MultipleDescriptorValues_HydroPower
# This query shows the list of Reservoirs in Utah that have HydroPower purpose


# 4.2MultiAttributeValues.csv
import urllib

# for simplicity, we call the query directly from GitHub as a text. You may use the query here but it will be too long to show in a cell 
# https://github.com/WamdamProject/WaMDaM_UseCases/blob/master/UseCases_files/4Queries_SQL/UseCase2/UseCase2.4/1_MultipleDescriptorValues_HydroPower.sql

txt1 = urllib.urlopen("https://raw.githubusercontent.com/WamdamProject/WaMDaM_UseCases/master/UseCases_files/4Queries_SQL/UseCase2/UseCase2.4/3_HydroPowerPlants_UT.sql").read()

# pass the query to the SQLite connection
df = pd.read_sql_query(txt1, conn)

# Save the query result into a CSV file
df.to_csv('query_resut.csv')

# to print the table result here within the notebook, just uncomment the df line below
df
# Out:
#    DatasetAcronymState                         InstanceNameState  \
# 0                NHAAP                           Deer Creek (UT)
# 1                NHAAP                             Flaming Gorge
# 2                NHAAP                              Spring Creek
# 3                NHAAP                              Spanish Fork
# 4                NHAAP                                    Payson
# 5                NHAAP                                    Causey
# 6                NHAAP                                   Wanship
# 7                NHAAP                                   Gateway
# 8                NHAAP                                  Olmstead
# 9                NHAAP                                  Echo Dam
# 10               NHAAP                             Pine View Dam
# 11               NHAAP                                   Pioneer
# 12               NHAAP                                Jordanelle
# 13               NHAAP                                    Uintah
# 14               NHAAP                                    Stairs
# 15               NHAAP                              Lower Monroe
# 16               NHAAP                              Upper Beaver
# 17               NHAAP                                     Hyrum
# 18               NHAAP                              Center Creek
# 19               NHAAP                                     Upper
# 20               NHAAP                                     Weber
# 21               NHAAP                               Yellowstone
# 22               NHAAP                      Beaver Lower Hydro 1
# 23               NHAAP                               Snake Creek
# 24               NHAAP                               Snake Creek
# 25               NHAAP                               Bartholomew
# 26               NHAAP                              Hobble Creek
# 27               NHAAP                         Upper Bartholomew
# 28               NHAAP                                   Boulder
# 29               NHAAP                              Cutler Hydro
# ..                 ...                                       ...
# 44               NHAAP                              Pigeon Creek
# 45               NHAAP                                      Veyo
# 46               NHAAP                                 Sand Cove
# 47               NHAAP                                   Gunlock
# 48               NHAAP                                Upper-Unit
# 49               NHAAP                                    Unit 4
# 50               NHAAP                                    Unit 3
# 51               NHAAP                                Lower-Unit
# 52               NHAAP                        Beaver Mid Hydro 2
# 53               NHAAP                             Lower Boulder
# 54               NHAAP                          Hydro Plant No 1
# 55               NHAAP                               Pine Valley
# 56               NHAAP                                   Granite
# 57               NHAAP                              Brigham City
# 58               NHAAP                                     Thayn
# 59               NHAAP                   Sixmile Creek Diversion
# 60               NHAAP                   Granite Creek Diversion
# 61               NHAAP                      Pah Tempe Powerhouse
# 62               NHAAP                  Granite Creek Powerhouse
# 63               NHAAP                   Cherry Grove Powerhouse
# 64               NHAAP                                Orderville
# 65               NHAAP     DeWitt Pipeline Hydroelectric Project
# 66               NHAAP          Big Willow Hydroelectric Project
# 67               NHAAP                        Monroe Cold Spring
# 68               NHAAP  Battle Creek Microhydro Power Generation
# 69               NHAAP                                 Box Elder
# 70               NHAAP                                 Coveville
# 71               NHAAP                                  Richmond
# 72               NHAAP      Ferron Water Treatment Plant Project
# 73               NHAAP                  Alta Micro-Hydro Project
#
#    DescriptorValueState
# 0                    UT
# 1                    UT
# 2                    UT
# 3                    UT
# 4                    UT
# 5                    UT
# 6                    UT
# 7                    UT
# 8                    UT
# 9                    UT
# 10                   UT
# 11                   UT
# 12                   UT
# 13                   UT
# 14                   UT
# 15                   UT
# 16                   UT
# 17                   UT
# 18                   UT
# 19                   UT
# 20                   UT
# 21                   UT
# 22                   UT
# 23                   UT
# 24                   UT
# 25                   UT
# 26                   UT
# 27                   UT
# 28                   UT
# 29                   UT
# ..                  ...
# 44                   UT
# 45                   UT
# 46                   UT
# 47                   UT
# 48                   UT
# 49                   UT
# 50                   UT
# 51                   UT
# 52                   UT
# 53                   UT
# 54                   UT
# 55                   UT
# 56                   UT
# 57                   UT
# 58                   UT
# 59                   UT
# 60                   UT
# 61                   UT
# 62                   UT
# 63                   UT
# 64                   UT
# 65                   UT
# 66                   UT
# 67                   UT
# 68                   UT
# 69                   UT
# 70                   UT
# 71                   UT
# 72                   UT
# 73                   UT
#
# [74 rows x 3 columns]

# %% [markdown]
# # Hydropower in California

# %% [markdown]
# ## HydroPower purpose in the US Major Dams dataset

# %%
# Query multiple MultipleDescriptorValues_HydroPower
# This query shows the list of Reservoirs in Utah that have HydroPower purpose in the US Major Dams dataset


# 4.2MultiAttributeValues.csv
import urllib

# for simplicity, we call the query directly from GitHub as a text. You may use the query here but it will be too long to show in a cell 
# https://github.com/WamdamProject/WaMDaM_UseCases/blob/master/UseCases_files/4Queries_SQL/UseCase2/UseCase2.4/1_MultipleDescriptorValues_HydroPower.sql

txt1 = urllib.urlopen("https://raw.githubusercontent.com/WamdamProject/WaMDaM_UseCases/master/UseCases_files/4Queries_SQL/UseCase2/UseCase2.4/4_HydroPower_CA_USDams.sql").read()

# pass the query to the SQLite connection
df = pd.read_sql_query(txt1, conn)

# Save the query result into a CSV file
df.to_csv('query_resut.csv')

# to print the table result here within the notebook, just uncomment the df line below
df
# Out:
#     DatasetAcronymPurpose             InstanceNamePurpose  \
# 0           US Major Dams                    BUCHANAN DAM
# 1           US Major Dams  SENATOR WASH - SQUAW LAKE DIKE
# 2           US Major Dams                    SENATOR WASH
# 3           US Major Dams                      SUTHERLAND
# 4           US Major Dams                   WOHLFORD LAKE
# 5           US Major Dams                   STEVENS CREEK
# 6           US Major Dams                   SANTA FELICIA
# 7           US Major Dams                       GIBRALTAR
# 8           US Major Dams                   CEDAR SPRINGS
# 9           US Major Dams                           QUAIL
# 10          US Major Dams                         PYRAMID
# 11          US Major Dams                        TERMINAL
# 12          US Major Dams                    ISABELLA DAM
# 13          US Major Dams                     SUCCESS DAM
# 14          US Major Dams                    TERMINUS DAM
# 15          US Major Dams                   PINE FLAT DAM
# 16          US Major Dams                     WISHON MAIN
# 17          US Major Dams          WISHON AUXILIARY NO. 1
# 18          US Major Dams                      COURTRIGHT
# 19          US Major Dams                      NORTH FORK
# 20          US Major Dams                      B. F. SISK
# 21          US Major Dams                 O NEILL FOREBAY
# 22          US Major Dams            BIG CREEK DAM NO. 3A
# 23          US Major Dams             BIG CREEK DAM NO. 2
# 24          US Major Dams             BIG CREEK DAM NO. 3
# 25          US Major Dams            BEAR CREEK DIVERSION
# 26          US Major Dams                         MCSWAIN
# 27          US Major Dams                  EXCHEQUER MAIN
# 28          US Major Dams                  EXCHEQUER DIKE
# 29          US Major Dams                DON PEDRO DIKE A
# ..                    ...                             ...
# 97          US Major Dams                    DRUM FOREBAY
# 98          US Major Dams            LAKE SPAULDING NO. 2
# 99          US Major Dams  LAKE SPAULDING NO. 3 AUXILIARY
# 100         US Major Dams                            BOCA
# 101         US Major Dams                       OUR HOUSE
# 102         US Major Dams                     FRENCH LAKE
# 103         US Major Dams             FAUCHERIE LAKE MAIN
# 104         US Major Dams           LAKE VALLEY AUXILIARY
# 105         US Major Dams                     BOWMAN ARCH
# 106         US Major Dams             THERMALITO AFTERBAY
# 107         US Major Dams              THERMALITO FOREBAY
# 108         US Major Dams                    FISH BARRIER
# 109         US Major Dams            THERMALITO DIVERSION
# 110         US Major Dams                        OROVILLE
# 111         US Major Dams                     STONY GORGE
# 112         US Major Dams                             POE
# 113         US Major Dams                          CRESTA
# 114         US Major Dams                 BLACK BUTTE DAM
# 115         US Major Dams                      ROCK CREEK
# 116         US Major Dams              WHISKEYTOWN DIKE 1
# 117         US Major Dams              WHISKEYTOWN DIKE 2
# 118         US Major Dams                PHILBROOK SADDLE
# 119         US Major Dams                     WHISKEYTOWN
# 120         US Major Dams                         KESWICK
# 121         US Major Dams                          SHASTA
# 122         US Major Dams                        LEWISTON
# 123         US Major Dams                         TRINITY
# 124         US Major Dams                      BOX CANYON
# 125         US Major Dams                       IRON GATE
# 126         US Major Dams                      COPCO NO 1
#
#     DescriptorValuePurpose DatasetAcronymState  \
# 0                        H       US Major Dams
# 1                        H       US Major Dams
# 2                        H       US Major Dams
# 3                        H       US Major Dams
# 4                        H       US Major Dams
# 5                        H       US Major Dams
# 6                        H       US Major Dams
# 7                        H       US Major Dams
# 8                        H       US Major Dams
# 9                        H       US Major Dams
# 10                       H       US Major Dams
# 11                       H       US Major Dams
# 12                       H       US Major Dams
# 13                       H       US Major Dams
# 14                       H       US Major Dams
# 15                       H       US Major Dams
# 16                       H       US Major Dams
# 17                       H       US Major Dams
# 18                       H       US Major Dams
# 19                       H       US Major Dams
# 20                       H       US Major Dams
# 21                       H       US Major Dams
# 22                       H       US Major Dams
# 23                       H       US Major Dams
# 24                       H       US Major Dams
# 25                       H       US Major Dams
# 26                       H       US Major Dams
# 27                       H       US Major Dams
# 28                       H       US Major Dams
# 29                       H       US Major Dams
# ..                     ...                 ...
# 97                       H       US Major Dams
# 98                       H       US Major Dams
# 99                       H       US Major Dams
# 100                      H       US Major Dams
# 101                      H       US Major Dams
# 102                      H       US Major Dams
# 103                      H       US Major Dams
# 104                      H       US Major Dams
# 105                      H       US Major Dams
# 106                      H       US Major Dams
# 107                      H       US Major Dams
# 108                      H       US Major Dams
# 109                      H       US Major Dams
# 110                      H       US Major Dams
# 111                      H       US Major Dams
# 112                      H       US Major Dams
# 113                      H       US Major Dams
# 114                      H       US Major Dams
# 115                      H       US Major Dams
# 116                      H       US Major Dams
# 117                      H       US Major Dams
# 118                      H       US Major Dams
# 119                      H       US Major Dams
# 120                      H       US Major Dams
# 121                      H       US Major Dams
# 122                      H       US Major Dams
# 123                      H       US Major Dams
# 124                      H       US Major Dams
# 125                      H       US Major Dams
# 126                      H       US Major Dams
#
#                   InstanceNameState DescriptorValueState
# 0                      BUCHANAN DAM                   CA
# 1    SENATOR WASH - SQUAW LAKE DIKE                   CA
# 2                      SENATOR WASH                   CA
# 3                        SUTHERLAND                   CA
# 4                     WOHLFORD LAKE                   CA
# 5                     STEVENS CREEK                   CA
# 6                     SANTA FELICIA                   CA
# 7                         GIBRALTAR                   CA
# 8                     CEDAR SPRINGS                   CA
# 9                             QUAIL                   CA
# 10                          PYRAMID                   CA
# 11                         TERMINAL                   CA
# 12                     ISABELLA DAM                   CA
# 13                      SUCCESS DAM                   CA
# 14                     TERMINUS DAM                   CA
# 15                    PINE FLAT DAM                   CA
# 16                      WISHON MAIN                   CA
# 17           WISHON AUXILIARY NO. 1                   CA
# 18                       COURTRIGHT                   CA
# 19                       NORTH FORK                   CA
# 20                       B. F. SISK                   CA
# 21                  O NEILL FOREBAY                   CA
# 22             BIG CREEK DAM NO. 3A                   CA
# 23              BIG CREEK DAM NO. 2                   CA
# 24              BIG CREEK DAM NO. 3                   CA
# 25             BEAR CREEK DIVERSION                   CA
# 26                          MCSWAIN                   CA
# 27                   EXCHEQUER MAIN                   CA
# 28                   EXCHEQUER DIKE                   CA
# 29                 DON PEDRO DIKE A                   CA
# ..                              ...                  ...
# 97                     DRUM FOREBAY                   CA
# 98             LAKE SPAULDING NO. 2                   CA
# 99   LAKE SPAULDING NO. 3 AUXILIARY                   CA
# 100                            BOCA                   CA
# 101                       OUR HOUSE                   CA
# 102                     FRENCH LAKE                   CA
# 103             FAUCHERIE LAKE MAIN                   CA
# 104           LAKE VALLEY AUXILIARY                   CA
# 105                     BOWMAN ARCH                   CA
# 106             THERMALITO AFTERBAY                   CA
# 107              THERMALITO FOREBAY                   CA
# 108                    FISH BARRIER                   CA
# 109            THERMALITO DIVERSION                   CA
# 110                        OROVILLE                   CA
# 111                     STONY GORGE                   CA
# 112                             POE                   CA
# 113                          CRESTA                   CA
# 114                 BLACK BUTTE DAM                   CA
# 115                      ROCK CREEK                   CA
# 116              WHISKEYTOWN DIKE 1                   CA
# 117              WHISKEYTOWN DIKE 2                   CA
# 118                PHILBROOK SADDLE                   CA
# 119                     WHISKEYTOWN                   CA
# 120                         KESWICK                   CA
# 121                          SHASTA                   CA
# 122                        LEWISTON                   CA
# 123                         TRINITY                   CA
# 124                      BOX CANYON                   CA
# 125                       IRON GATE                   CA
# 126                      COPCO NO 1                   CA
#
# [127 rows x 6 columns]

# %% [markdown]
# <a id='section4'></a>
# ### 4. Creating a new HydroShare resource
#
# The best way to save your data is to put it back into HydroShare and is done using the `createHydroShareResource` function. The first step is to identify the files you want to save to a HydroShare.  The cell below lists all the files in the current working directory.

# %%
# Grab all the files in the folder where you are working  
files = !ls
print('My files: %s' % files)
# Out:
# My files: ['2.4_plotcdf.html', 'CDF_data.csv', 'Filtered Data.csv', 'query_resut2.csv', 'query_resut.csv', 'UseCase2.2_dentifyDemandSites_TimeSeriesValues.html', 'WaMDaM_UseCase1.ipynb', 'WaMDaM_Use_Case2.1.ipynb', 'WaMDaM_Use_Case2.2.ipynb', 'WaMDaM_Use_Case2.3.ipynb', 'WaMDaM_Use_Case2.4.ipynb', 'WaMDaM_UseCase3.ipynb', 'WaMDaM_Use_Cases_Overview.ipynb']

# %%
# lets save this content as a new resource in HydroShare
abstract = 'This is a demo of the HydroShare Python Notebook Server for WaMDaM'
title = 'WaMDaM_Use_Case2.4'    
keywords = ['Demo', 'JupyterHub']  
rtype = 'genericresource'          

# create a list of files that will be added to the HydroShare resource.
#files = ['WaMDaM_use_cases_Multi_columns.ipynb.ipynb']  # this notebook
        
# create a list of files that will be added to the HydroShare resource.
    
files = [hs.content['BearRiverDatasets_Jan2018.sqlite'],'WaMDaM_Use_Case2.4.ipynb']

# %%
    
# create the new resource
resource_id = hs.createHydroShareResource(abstract, 
                                          title, 
                                          keywords=keywords, 
                                          resource_type=rtype, 
                                          content_files=files, 
                                          public=True)
# Out:
# Resource Created Successfully
# Successfully Added Content Files
# Resource id: ad194fccc3954100b438f0e324a4ccfb
# <a href=https://www.hydroshare.org/resource/ad194fccc3954100b438f0e324a4ccfb target="_blank">Open Resource in HydroShare<a>
